# %% [markdown]
# ### LangChain V1

# %%
import os
from dotenv import load_dotenv

load_dotenv()
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.agents import create_agent

# Load environment variables
load_dotenv("../.env")

# Create the Gemini model
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0
)

# Create the agent
agent = create_agent(
    model=llm,
    tools=[],
    system_prompt="You are a helpful AI assistant."
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 3
#       1 from dotenv import load_dotenv
#       2 from langchain_google_genai import ChatGoogleGenerativeAI
# ----> 3 from langchain.agents import create_agent
#       4
#       5 # Load environment variables
#       6 load_dotenv("../.env")
#
# ImportError: cannot import name 'create_agent' from 'langchain.agents' (c:\Projects\Langchaincourse\.venv\Lib\site-packages\langchain\agents\__init__.py)

# %%
import langchain
print(langchain.__version__)
# Out:
# 0.1.0

# %%
import langchain

print(langchain.__version__)
print(langchain.__file__)
# Out:
# 0.1.0
# c:\Projects\Langchaincourse\.venv\Lib\site-packages\langchain\__init__.py
